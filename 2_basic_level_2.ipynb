# %%
import datasets
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')

df = dataset['train'].to_pandas()
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# 9. Show all jobs where country is "India"

# %%
 #Jobs from India
df_india = df[df['job_country'] == 'India']
df_india['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Engineer                19062
# Data Scientist               13279
# Data Analyst                  6121
# Senior Data Engineer          4353
# Senior Data Scientist         2486
# Business Analyst              1887
# Software Engineer             1795
# Senior Data Analyst           1083
# Machine Learning Engineer      671
# Cloud Engineer                 351
# Name: count, dtype: int64

# %% [markdown]
# 10.	How many jobs are work-from-home?

# %%
#WFH jobs
df['job_work_from_home'].value_counts() 
df[df['job_work_from_home'] == True].shape
# Out:
# (69552, 17)

# %% [markdown]
# 11. Filter jobs with salary greater than 1,00,000

# %%
df_job_salary = df[df['salary_year_avg'] > 100000]
df_job_salary['job_title'].value_counts().head(10)
# Out:
# job_title
# Data Scientist              1091
# Data Engineer                940
# Senior Data Engineer         694
# Senior Data Scientist        517
# Data Analyst                 347
# Senior Data Analyst          200
# Lead Data Engineer           185
# Lead Data Scientist          152
# Sr. Data Engineer            114
# Principal Data Scientist     105
# Name: count, dtype: int64

# %% [markdown]
# 12. Jobs that don't require a degree

# %%
df['job_no_degree_mention'].value_counts()
df[df['job_no_degree_mention'] == True]
# Out:
#              job_title_short  \
# 3              Data Engineer
# 10             Data Engineer
# 13      Senior Data Engineer
# 25       Senior Data Analyst
# 26             Data Engineer
# ...                      ...
# 785698         Data Engineer
# 785700         Data Engineer
# 785701         Data Engineer
# 785703          Data Analyst
# 785706         Data Engineer
#
#                                                 job_title  \
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 10                   Erfahrene*r Data Engineer*in (m/w/d)
# 13                                   Senior Data Engineer
# 25                      Senior Officer, Data Analyst, GTO
# 26                                          Data Engineer
# ...                                                   ...
# 785698      Data Engineer, Gerencia Business Intelligence
# 785700                               Data Engineer Ssr/Sr
# 785701      Data Engineer, Gerencia Business Intelligence
# ...

# %% [markdown]
# 13. Jobs posted in the last 30 days

# %%
import pandas as pd
from datetime import datetime ,timedelta
df['date'] = pd.to_datetime(df['job_posted_date'])

today = datetime.today()
last_30_days = today - timedelta(days=30)
recent_jobs = df[df['date'] >= last_30_days]
len(recent_jobs)
# Out:
# 0

# %% [markdown]
# 14. Count jobs by "job_schedule_type".

# %%
df['job_schedule_type'].value_counts()
# Out:
# job_schedule_type
# Full-time                                701727
# Contractor                                34793
# Internship                                 8742
# Part-time                                  7881
# Full-time and Part-time                    6287
# Full-time and Temp work                    2603
# Full-time and Internship                   2340
# Full-time and Contractor                   2292
# Contractor and Temp work                   2283
# Temp work                                  2169
# Full-time, Part-time, and Internship        264
# Part-time and Internship                    255
# Temp work and Internship                    211
# Full-time, Contractor, and Temp work        194
# Full-time, Temp work, and Internship        173
# Part-time and Contractor                    160
# Full-time, Part-time, and Temp work         131
# Full-time, Part-time, and Contractor        119
# Part-time and Temp work                     111
# ...

# %% [markdown]
# 15. Filter jobs by a specific company

# %%
df['company_name'].value_counts().head(10)
df[df['company_name'] == 'Dice']
# Out:
#              job_title_short  \
# 2330           Data Engineer
# 3091           Data Engineer
# 4347           Data Engineer
# 8548          Data Scientist
# 8871           Data Engineer
# ...                      ...
# 769003  Senior Data Engineer
# 769633      Business Analyst
# 769842        Data Scientist
# 772618         Data Engineer
# 775073         Data Engineer
#
#                                                 job_title       job_location  \
# 2330                                        Data Engineer           Anywhere
# 3091                                  Azure Data Engineer     Birmingham, AL
# 4347                                    EDF Data Engineer         Austin, TX
# 8548                Data Scientist - Content Intelligence          Tempe, AZ
# 8871    AWS Data Engineer Hybrid (Independent candidat...           Anywhere
# ...                                                   ...                ...
# ...

# %% [markdown]
# 16. Jobs where salary is missing

# %%
df[df['salary_year_avg'].isnull() == True]
df[['job_title_short', 'salary_year_avg']]
# Out:
#              job_title_short  salary_year_avg
# 0       Senior Data Engineer              NaN
# 1               Data Analyst              NaN
# 2              Data Engineer              NaN
# 3              Data Engineer              NaN
# 4              Data Engineer              NaN
# ...                      ...              ...
# 785736     Software Engineer              NaN
# 785737          Data Analyst              NaN
# 785738      Business Analyst              NaN
# 785739         Data Engineer              NaN
# 785740     Software Engineer              NaN
#
# [785741 rows x 2 columns]

# %% [markdown]
# 17. Jobs that mention Python in skills

# %%
python_jobs = df[df['job_skills'].str.contains('Python', case=False, na=False)]
python_jobs
# Out:
#              job_title_short  \
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# 5              Data Engineer
# ...                      ...
# 785731         Data Engineer
# 785732         Data Engineer
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785739         Data Engineer
#
#                                                 job_title  \
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785735                               Senior Data Engineer
# ...
